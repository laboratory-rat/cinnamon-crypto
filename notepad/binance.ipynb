# %%
from src.application.service.candlestick_data import CandlestickDataService
import uuid

from src.application.di import AppModule
from injector import Injector
from src.infrastructure.config.app_config import AppConfig
import pandas as pd


config = AppConfig()
injector = Injector([AppModule(config)])

coin_pair_id = uuid.UUID('b850d573ce724dd0b202b7cad62fb5d6')
coin_pair_service = injector.get(CandlestickDataService)
total_count = coin_pair_service.count_by_coin_pair(coin_pair_id)
schemas = coin_pair_service.filter_by_coin_pair(coin_pair_id, limit=total_count)

df = pd.DataFrame([schema.model_dump() for schema in schemas])
# Out:
#                                       id    created_at    updated_at  \
# 0   33897597-1318-4e5a-9270-c5479d83f4ec  1.715782e+09  1.715782e+09
# 1   13e83e9b-ab28-45ac-a765-286aac856026  1.715782e+09  1.715782e+09
# 2   7c54c315-f0cf-4773-ae33-4de0044196d3  1.715782e+09  1.715782e+09
# 3   f35c14d3-32a4-4cc6-a8b5-9058d1af5029  1.715782e+09  1.715782e+09
# 4   c882f545-c7f7-41f4-9914-c00ca958fbff  1.715782e+09  1.715782e+09
# 5   31dca3c2-11f0-49dc-aa6f-c6ba82de41d1  1.715782e+09  1.715782e+09
# 6   f2c2d45b-d6cc-4256-9196-27e94ccc10de  1.715782e+09  1.715782e+09
# 7   c31bb280-05a7-4fc8-9d5a-5c73f60fe1e0  1.715782e+09  1.715782e+09
# 8   3ba6daf5-ea2d-4a8b-a2d0-02963d0e1f74  1.715782e+09  1.715782e+09
# 9   b540868b-f1b8-4976-80fa-bab2ec1fd60e  1.715782e+09  1.715782e+09
# 10  e0da7ef5-df89-40b5-a261-0432d944b726  1.715782e+09  1.715782e+09
# 11  7649ed3c-94dc-4935-a7db-2b5e321a82ce  1.715782e+09  1.715782e+09
# 12  1cda5a29-e29e-4503-a803-6d9b17ebd8b8  1.715782e+09  1.715782e+09
# ...
